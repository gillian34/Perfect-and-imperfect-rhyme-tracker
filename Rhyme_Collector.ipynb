# %% [markdown]
# #Code to extract perfect and imperfect rhymes from songs.
# Please upload rhyming_dictionaries.pickle and billboard_lyrics.csv before preceeding. They can be found in the same github repository.

# %% [markdown]
# Imports necessary packages and libraries

# %%
# imports packages
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re

# !pip install nltk

import nltk

import pickle
import os
from nltk.tokenize import word_tokenize
nltk.download('punkt') # may be needed the first time
import difflib
import string
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2024.9.11)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.5)
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %% [markdown]
# The methods below were written by Andrei Popescu-Belis, Àlex R. Atrio, Bastien Bernath, Etienne Boisson, Teo Ferrari, Xavier Theimer-Lienhard, Giorgos Vernikos. They were not modified by me.

# %%
'''
gets a rhyming dictionary created by the authors listed above.
To run this method, upload rhyming_dictionaries from github.
'''
def get_rhyming_dictionary(path="/content/rhyming_dictionaries (1).pickle"):
    with open(path,"rb") as fd:
        word2rhymes, _, _ = pickle.load(fd)
    return word2rhymes


'''
    Returns an array with two elements: (1) the perfect rhyme and (2) the assonant
    rhyme of the verse (its last word, except punctuations and contractions).
    If the word is not found in the dictionary, it looks for the most similar one.
'''
def verse2rhyme(verse, rhyme_dict):
    punctuation = ['.', ',', ',', ':', ';', '!', '?', ' ', '-', '...', '_']
    verse = verse.replace('’', '\'')
    v = word_tokenize(verse)
    v = [w for w in v if w not in punctuation] # remove all punctuations
    if len(v) == 0:
        return []
    if v[-1] == 'n\'t':             # tokenizer's output on contraction: don't -> do, n't
        final_word = v[-2] + v[-1]  # restore full form (v[-2] is necessarily present)
    elif v[-1] == '\'d':            # for contraction of past participle (Shakespeare!)
        final_word = v[-2] + 'ed'
    else:
        final_word = v[-1]
    final_word = final_word.lower()
    if final_word not in rhyme_dict: # find a similar word that *is* in the dictionary
        similar_words = difflib.get_close_matches(final_word, rhyme_dict.keys(), n=1) # time consuming
        if similar_words == []:
            return ['', ''] # if it couldn't find anything
        else:
            return rhyme_dict[similar_words[0]]
    return rhyme_dict[final_word]

# %% [markdown]
# The methods below were created and modified by me.

# %%
'''
method to get information about a specific year
'''
def df_year(year):
  df_year = df.loc[df["Year"] == year]
  return df_year

'''
takes in a poem (or song), a rhyming dictionary, and two empty lists.
Returns full lists of all perfect and imperfect rhymes in the song.
Some lines of code taken from Popescu et. al.
'''
def print_all_rhymes(poem, rhyme_dict, types_perfect, types_imperfect):
    global stanzas_total
    global stanzas_examined
    stanzas_total = stanzas_total +1
    num_perfect = 0
    num_imperfect = 0
    num_not = 0
    real = True
    lines = poem.split('\n')
    # only counts imperfect rhmyes in stanzas that fit the requirements of length
    #and not too long-distance (based on prelimilary research from looking at the corpus)
    if len(lines) <2:
      return types_perfect, types_imperfect
    if len(lines) > 6:
      return types_perfect, types_imperfect
    # counts number of stanzas examined
    stanzas_examined = stanzas_examined +1
    #accounts for the case when the lines have unnecssary spaces:
    for index, p in enumerate(lines):
      if p == '':
        lines.remove(lines[index])
    for index, p in enumerate(lines):
      if p.isspace():
        lines.remove(lines[index])
    # gets the rhyming parts of each word
    rhymes = [verse2rhyme(line, rhyme_dict) for line in lines]
    # goes through and compares each line to the other
    for i in range(len(lines)):
        for j in range(len(lines)-1):
            if rhymes[i] == [] or rhymes[j] == []:
              real == True
            elif j >= i:
                real == True
            # Makes to not to count any rhymes that are caused simply by words that are the same
            elif (lines[i].split(" "))[-1] == (lines[j].split(" "))[-1]:
              real = True
            # if statement in case the words do make a perfect rhyme
            elif rhymes[i][0] == rhymes[j][0]:
                num_perfect = num_perfect+1
                if rhymes[i][0] in types_perfect.keys():
                  types_perfect[rhymes[i][0]] = types_perfect[rhymes[i][0]]+1
                else:
                  types_perfect[rhymes[i][0]] = 1
            # if statement in case the words do make an imperfect rhyme
            elif rhymes[i][1] == rhymes[j][1]:
                num_imperfect = num_imperfect+1
                if (rhymes[i][0], rhymes[j][0]) in types_imperfect.keys():
                  types_imperfect[(rhymes[i][0], rhymes[j][0])] = types_imperfect[(rhymes[i][0], rhymes[j][0])] +1
                else:
                  types_imperfect[(rhymes[i][0], rhymes[j][0])] = 1
            else:
                num_not = num_not+1
    return types_perfect, types_imperfect

'''
Method inputs include a song, two emtpy lists, and a couting variable. The method
outputs the imperfect and perfect rhymes and counts if the song was too short.
'''
def one_song_rhymes(Current_song, types_perfect, types_imperfect, not_enough_stanzas):
  punctuation = ['.', ',', ',', ':', ';', '!', '?', ' ', '-', '...', '_']
  stanzas = Current_song.split("\n\n")
  if len(stanzas) ==1:
    stanzas = Current_song.split("\n\r")
  if len(stanzas) <3:
    not_enough_stanzas = not_enough_stanzas+1
    return types_perfect, types_imperfect, not_enough_stanzas
  for stanza in stanzas:
    stanza = stanza.replace('[].,,:!? -..._]', '')
    stanza = stanza.replace('\r', '')
    stanza = stanza.replace('"', '')
    types_perfect, types_imperfect = print_all_rhymes(stanza, word2rhymes, types_perfect, types_imperfect)
  return types_perfect, types_imperfect, not_enough_stanzas

# %% [markdown]
# Code to call methods above

# %%
#creates the rhyming dictionary
word2rhymes = get_rhyming_dictionary()

#reads the csv
df = pd.read_csv("billboard_lyrics.csv")

#defines global variables
global stanzas_examined
global stanzas_total

# creates variables
df_year = df

types_perfect = {}
types_imperfect = {}
invalid_lyrics = 0
instrumental = 0
not_enough_stanzas = 0

stanzas_examined = 0
stanzas_total = 0

# cleans up a song and then calls the one song rhymes method.
for index, row in df_year.loc[:, ['Lyrics']].iterrows():
  Current_song = row['Lyrics']
  if Current_song.startswith("sorry, we have no") | Current_song.startswith("we do not have the lyrics for") :
    invalid_lyrics = invalid_lyrics+1
    continue
  # accounts for songs with no lyrics
  if (Current_song == "[instrumental]"):
    invalid_lyrics = invalid_lyrics + 1
    instrumental = instrumental +1
  cleaned_lyrics = re.sub(" him: | her: |both:", '', Current_song, flags=re.MULTILINE)
  cleaned_lyrics2 = re.sub("\[.*?\]", '', cleaned_lyrics)
  cleaned_twice = re.sub("[^0-9a-zA-Z\n\r ']+", '', cleaned_lyrics2)
  types_perfect, types_imperfect, not_enough_stanzas = one_song_rhymes(cleaned_twice, types_perfect, types_imperfect, not_enough_stanzas)
  print(index, row)

#prints the perfect and imperfect rhymes and other statistics about the data
print("perfect")
print(types_perfect)
print("imperfect")
print(types_imperfect)
print(index)
print("invalid" + str(invalid_lyrics))
print("instrumental")
print(instrumental)
print("not_enough_stanzas")
print(not_enough_stanzas)
print("total stanzas")
print(stanzas_total)
print("stanzas examined")
print(stanzas_examined)
# Out:
# 0 Lyrics    uno, dos, one, two, tres, quatro\nmatty told h...
# Name: 0, dtype: object
# 1 Lyrics    ooh, sugar pie, honey bunch\nyou know that i l...
# Name: 1, dtype: object
# 2 Lyrics    hey look\ni can't get no satisfaction\ni can't...
# Name: 2, dtype: object
# 3 Lyrics    verse 1\n\nwhen i woke up this morning\nyou we...
# Name: 3, dtype: object
# 4 Lyrics    you never close your eyes anymore when i kiss ...
# Name: 4, dtype: object
# 5 Lyrics    when you're alone and life is making you lonel...
# Name: 5, dtype: object
# 6 Lyrics    help, i need somebody\nhelp, not just anybody\...
# Name: 6, dtype: object
# 7 Lyrics    every time i see you lookin' my way\nbaby, bab...
# Name: 7, dtype: object
# 8 Lyrics    you saw me crying in the chapel\nthe tears i s...
# Name: 8, dtype: object
# 9 Lyrics    i've got sunshine\r\non a cloudy day\r\nwhen i...
# Name: 9, dtype: object
# 10 Lyrics    well since she put me down i 've been out doin...
# Name: 10, dtype: object
# 11 Lyrics    trailer for sale or rent, rooms to let, fifty ...
# Name: 11, dtype: object
# 12 Lyrics    let me tell ya 'bout the birds and the bees\na...
# Name: 12, dtype: object
# 13 Lyrics    hold me, hold me\nnever let me go until you've...
# Name: 13, dtype: object
# 14 Lyrics    shotgun 2: 58 trk 1\n(autry dewalt aka junior ...
# Name: 14, dtype: object
# 15 Lyrics    sonny\nmiscellaneous\ni got you babe\ni got yo...
# Name: 15, dtype: object
# 16 Lyrics    who wants to buy\nthis diamond ring?\nshe took...
# Name: 16, dtype: object
# 17 Lyrics    [instrumental]
# Name: 17, dtype: object
# 18 Lyrics    not set yet.
# Name: 18, dtype: object
# 19 Lyrics    stop! in the name of love\nbefore you break my...
# Name: 19, dtype: object
# 20 Lyrics    oh, my love, my darling\ni've hungered for you...
# Name: 20, dtype: object
# 21 Lyrics    took a walk and passed your house late last ni...
# Name: 21, dtype: object
# 22 Lyrics    the seekers\nmiscellaneous\ni'll never find an...
# Name: 22, dtype: object
# 23 Lyrics    (*mantovani)\n\n\ncara mia why must we say goo...
# Name: 23, dtype: object
# 24 Lyrics    not set yet.
# Name: 24, dtype: object
# 25 Lyrics    a month of nights, a year of days\noctobers dr...
# Name: 25, dtype: object
# 26 Lyrics    i don't even know how to love you\njust the wa...
# Name: 26, dtype: object
# 27 Lyrics    not set yet.
# Name: 27, dtype: object
# 28 Lyrics    bloody board destruction\n\ni wake up and i se...
# Name: 28, dtype: object
# 29 Lyrics    hang on, sloopy\nsloopy, hang on\nhang on, slo...
# Name: 29, dtype: object
# 30 Lyrics    i think i'm gonna be sad\ni think it's today, ...
# Name: 30, dtype: object
# 31 Lyrics    i want some red roses for a blue lady\nmr. flo...
# Name: 31, dtype: object
# 32 Lyrics    come here sister papa's in the swing\r\nhe ain...
# Name: 32, dtype: object
# 33 Lyrics    the purpose of a man is to love a woman\nand t...
# Name: 33, dtype: object
# 34 Lyrics    the name game!\nshirley!\nshirley, shirley bo ...
# Name: 34, dtype: object
# 35 Lyrics    every day when the work is behind you\nand the...
# Name: 35, dtype: object
# 36 Lyrics    all day long i hear my telephone ring\nfriends...
# Name: 36, dtype: object
# 38 Lyrics    in the valley of the jolly\n\nheard about the ...
# Name: 38, dtype: object
# 39 Lyrics    hush hush, sweet charlotte\ncharlotte, don't y...
# Name: 39, dtype: object
# 40 Lyrics    once upon a time you dressed so fine\nthrew th...
# Name: 40, dtype: object
# 41 Lyrics    freddie\nmiscellaneous\ni'm telling you now\ni...
# Name: 41, dtype: object
# 42 Lyrics    gerry\nmiscellaneous\nferry 'cross the mersey\...
# Name: 42, dtype: object
# 43 Lyrics    the righteous brothers\nmiscellaneous\njust on...
# Name: 43, dtype: object
# 44 Lyrics    everybody talkin' 'bout the seventh son\n in t...
# Name: 44, dtype: object
# 46 Lyrics    [original is an instrumental music]\n[vocals r...
# Name: 46, dtype: object
# 47 Lyrics    for your love.\nfor your love.\nfor your love....
# Name: 47, dtype: object
# 48 Lyrics    well, east coast girls are hip, i really dig t...
# Name: 48, dtype: object
# 49 Lyrics    we've already said goodbye\nsince you gotta go...
# Name: 49, dtype: object
# 50 Lyrics    goldfinger, he's the man\nthe man with the mid...
# Name: 50, dtype: object
# 51 Lyrics    down in the boondocks\ndown in the boondocks\n...
# Name: 51, dtype: object
# 52 Lyrics    some men climb a mountain\nsome men swim the s...
# Name: 52, dtype: object
# 53 Lyrics    here they come again, mmm\ncatch us if you can...
# Name: 53, dtype: object
# 54 Lyrics    ooh, i need your love, babe\r\nguess you know ...
# Name: 54, dtype: object
# 55 Lyrics    i can't stay, yes i know\nyou know i hate to g...
# Name: 55, dtype: object
# 56 Lyrics    ian whitcomb\nmiscellaneous\nyou turn me on (t...
# Name: 56, dtype: object
# 57 Lyrics    well, i'll be doggone if i wouldn't work all d...
# Name: 57, dtype: object
# 58 Lyrics    gary lewis and the playboys\ngolden greats\nsa...
# Name: 58, dtype: object
# 59 Lyrics    so tired, tired of waiting\r\ntired of waiting...
# Name: 59, dtype: object
# 60 Lyrics    gary lewis\nmiscellaneous\ncount me in\ncount ...
# Name: 60, dtype: object
# 61 Lyrics    and here come the kinks with, 'all day and all...
# Name: 61, dtype: object
# 62 Lyrics    what the world needs now is love, sweet love\n...
# Name: 62, dtype: object
# 63 Lyrics    it's not unusual to be loved by anyone\nit's n...
# Name: 63, dtype: object
# 64 Lyrics    well, she was walking down the street\nlooking...
# Name: 64, dtype: object
# 65 Lyrics    shake\nshake\nshake\nshake\n\nlisten\n\nlisten...
# Name: 65, dtype: object
# 66 Lyrics    don't know much about history\r\ndon't know mu...
# Name: 66, dtype: object
# 67 Lyrics    nowhere to run to baby, nowhere to hide\ni got...
# Name: 67, dtype: object
# 68 Lyrics    sick at heart and lonely\ndeep in dark despair...
# Name: 68, dtype: object
# 69 Lyrics    not set yet.
# Name: 69, dtype: object
# 70 Lyrics    last night at the dance i met laurie,\nso love...
# Name: 70, dtype: object
# 71 Lyrics    sonny\nmiscellaneous\nbaby don't go\nbaby don'...
# Name: 71, dtype: object
# 72 Lyrics    go away from my window\nleave at your own chos...
# Name: 72, dtype: object
# 73 Lyrics    and if she should tell you "come closer"\r\nan...
# Name: 73, dtype: object
# 74 Lyrics    peter\nmiscellaneous\ni go to pieces\ni go to ...
# Name: 74, dtype: object
# 75 Lyrics    vic dana\nmiscellaneous\nred roses for a blue ...
# Name: 75, dtype: object
# 76 Lyrics    please don't just stand there\ncome and kiss m...
# Name: 76, dtype: object
# 77 Lyrics    people say i'm the life of the party\n'cause i...
# Name: 77, dtype: object
# 78 Lyrics    i wish i could come back to you dear\n'cause i...
# Name: 78, dtype: object
# 79 Lyrics    come on\n(come on, let me show you where it's ...
# Name: 79, dtype: object
# 80 Lyrics    little things that you do \r\nmake me glad i'm...
# Name: 80, dtype: object
# 81 Lyrics    peter\nmiscellaneous\ntrue love ways\ntrue lov...
# Name: 81, dtype: object
# 82 Lyrics    you're sweet (you're sweet)\nas a honeybee\nbu...
# Name: 82, dtype: object
# 83 Lyrics    i see that worried look upon your face,\r\nyou...
# Name: 83, dtype: object
# 84 Lyrics    hold what you've got 3: 08 trk 5\n(joe tex)\nj...
# Name: 84, dtype: object
# 85 Lyrics    midnight finds me cryin'\nday time finds me cr...
# Name: 85, dtype: object
# 86 Lyrics    the beau brummels\nmiscellaneous\nlaugh laugh\...
# Name: 86, dtype: object
# 87 Lyrics    well i told you once and i told you twice\nbut...
# Name: 87, dtype: object
# 88 Lyrics    do you believe in magic?\nin a young girls hea...
# Name: 88, dtype: object
# 89 Lyrics    now i ain't lookin' to compete with you\nbeat ...
# Name: 89, dtype: object
# 90 Lyrics    take me back, i'm beggin' please\ntake me back...
# Name: 90, dtype: object
# 91 Lyrics    i know a girl who's soft and sweet\nshe's so f...
# Name: 91, dtype: object
# 92 Lyrics    i did you wrong\nmy heart went out to play\nan...
# Name: 92, dtype: object
# 93 Lyrics    songwriters: bono, sonny\n\nwhy can't i, be li...
# Name: 93, dtype: object
# 94 Lyrics    i wanna tell you a story \nevery man oughta kn...
# Name: 94, dtype: object
# 95 Lyrics    i feel tears wellin' up cold and deep inside\n...
# Name: 95, dtype: object
# 96 Lyrics    you know where i can be found\ndon't you know ...
# Name: 96, dtype: object
# 97 Lyrics    oo ah oo ah oo oo, kitty\ntell us about the bo...
# Name: 97, dtype: object
# 98 Lyrics    no one will understand what i've gotta do\ni'v...
# Name: 98, dtype: object
# 99 Lyrics    how sweet it is to be loved by you, yes, baby\...
# Name: 99, dtype: object
# perfect
# {'uw': 56, 'iy': 52, 'ahn': 13, 'aynd': 11, 'uwz': 4, 'ihps': 1, 'ey': 25, 'awnd': 3, 'eyz': 4, 'aord': 1, 'ehd': 2, 'aen': 2, 'ay': 30, 'uwm': 2, 'owz': 1, 'ow': 24, 'ehnt': 1, 'aat': 1, 'ihng': 7, 'aong': 2, 'aor': 9, 'er': 7, 'ayt': 30, 'eyd': 1, 'iyt': 5, '': 3, 'ayd': 8, 'ehr': 12, 'iyz': 8, 'aart': 2, 'aend': 3, 'aed': 3, 'ayl': 1, 'oyz': 2, 'aw': 2, 'ays': 2, 'aens': 1, 'ayz': 5, 'uwk': 1, 'awd': 1, 'own': 10, 'aet': 3, 'ahv': 8, 'ihn': 5, 'owld': 4, 'ihl': 1, 'aek': 1, 'aym': 4, 'ehl': 1, 'aon': 17, 'ehnd': 1, 'uhd': 1, 'awt': 1, 'uwp': 1, 'ihp': 1, 'owl': 4, 'ahm': 1, 'eyv': 1, 'iyd': 1, 'awn': 3, 'eys': 8, 'aost': 2, 'erv': 1, 'ert': 1, 'ayn': 1}
# imperfect
# {('ehls', 'ehlf'): 2, ('ayd', 'ay'): 3, ('ahn', 'ahm'): 4, ('uwsh', 'uwz'): 2, ('uwz', 'uwsh'): 2, ('iht', 'ihps'): 2, ('iyz', 'iy'): 2, ('ehrz', 'ehr'): 2, ('awnd', 'awn'): 9, ('iyt', 'iy'): 4, ('aar', 'aa'): 1, ('ayn', 'aym'): 1, ('ahnt', 'ahl'): 1, ('erth', 'ercht'): 1, ('erth', 'erch'): 1, ('aym', 'ayn'): 3, ('ehts', 'ehnts'): 2, ('eymz', 'eyn'): 1, ('ahl', 'ahn'): 2, ('iht', 'ihd'): 2, ('ays', 'ayts'): 1, ('ahn', 'ahnt'): 1, ('aap', 'aart'): 1, ('ayz', 'ayt'): 2, ('aym', 'ay'): 5, ('ae', 'aed'): 2, ('aed', 'ae'): 1, ('ays', 'ay'): 3, ('ay', 'ays'): 1, ('ahv', 'ahn'): 8, ('ehr', 'ehrz'): 1, ('ayts', 'ays'): 4, ('iyn', 'iy'): 1, ('aan', 'aaz'): 1, ('awd', 'awt'): 2, ('own', 'owm'): 8, ('owm', 'own'): 4, ('eyb', 'eyd'): 1, ('uwz', 'uw'): 2, ('ahn', 'ahs'): 3, ('aed', 'aes'): 1, ('aen', 'aes'): 1, ('aen', 'aed'): 1, ('ehdz', 'ehd'): 2, ('iyz', 'iyr'): 2, ('ehn', 'ehr'): 1, ('ehr', 'ehn'): 2, ('aend', 'aen'): 1, ('erld', 'erlz'): 1, ('aaz', 'aaks'): 4, ('aaks', 'aaz'): 2, ('ey', 'eyv'): 1, ('ae', 'aen'): 3, ('iyk', 'iy'): 6, ('aym', 'aynd'): 2, ('ahs', 'ahm'): 1, ('ahm', 'ahs'): 1, ('awn', 'awnd'): 3, ('ayk', 'ayf'): 2, ('ihn', 'ihs'): 3, ('awt', 'awn'): 1, ('awt', 'awnd'): 1, ('awnt', 'awn'): 1, ('awnt', 'awnd'): 1, ('awnt', 'awt'): 1, ('ayd', 'aym'): 2, ('aym', 'ayd'): 3, ('aym', 'ayt'): 1, ('ayt', 'aym'): 1, ('ahn', 'ahv'): 9, ('iy', 'iyt'): 4, ('eym', 'ey'): 1, ('ey', 'eym'): 1, ('aw', 'awnd'): 1, ('ihp', 'ihps'): 2, ('owl', 'ow'): 3, ('erld', 'erl'): 1, ('owld', 'owm'): 1, ('aark', 'aard'): 1, ('ahz', 'ahs'): 2, ('ahn', 'ahz'): 4, ('iyk', 'iyt'): 1, ('ay', 'ayd'): 9, ('ahs', 'ah'): 1, ('ahn', 'aht'): 1, ('aynd', 'ayn'): 2, ('uwt', 'uw'): 1, ('ihjh', 'ihr'): 1, ('aos', 'aost'): 4, ('aet', 'aek'): 1, ('aon', 'aong'): 4, ('aong', 'aon'): 2, ('aat', 'aan'): 3, ('aan', 'aat'): 1, ('ihl', 'iht'): 2, ('ow', 'owm'): 1, ('ey', 'eyks'): 1, ('ihl', 'ihm'): 1, ('ihn', 'ihng'): 3, ('ihng', 'ihn'): 2, ('ahp', 'aht'): 2, ('ey', 'eys'): 2, ('ahs', 'ahl'): 1, ('uwl', 'uw'): 1, ('ehlf', 'ehls'): 1, ('aarts', 'aart'): 1, ('iy', 'iyz'): 8, ('er', 'erd'): 1, ('aym', 'ayv'): 1, ('uw', 'uwl'): 4, ('uw', 'uwt'): 1, ('ayf', 'ayt'): 1}
# 99
# invalid3
# instrumental
# 1
# not_enough_stanzas
# 17
# total stanzas
# 642
# stanzas examined
# 530

# %% [markdown]
# Once the data has been obtained, the following methods sort and organize the data.

# %%
'''
code taken from: https://www.geeksforgeeks.org/python-sort-python-dictionaries-by-key-or-value/
'''
def sort_dict(my_dict):
  keys = list(my_dict.keys())
  values = list(my_dict.values())
  sorted_value_index = np.argsort(values)
  my_dict2 = {keys[i]: values[i] for i in sorted_value_index}
  my_dict3 = dict(reversed(list(my_dict2.items())))
  return my_dict3

'''
Sorts a dictionary.
For this method, I ignore which came first in the rhyme, but if you want that,
 just delete the frozenset word. Rhyme counts account for only the last consonant
'''
def consonant_only(my_dict):
  no_vowels = dict()
  for key in my_dict:
    new_key0 = re.sub("[aeiouyh]", "", key[0])
    new_key1 = re.sub("[aeiouyh]", "", key[1])
    if len(new_key0) > 1:
      new_key0 = new_key0[-1]
    if len(new_key1) > 1:
      new_key1 = new_key1[-1]
    new_key = (new_key0, new_key1)
    new_key = frozenset(new_key)
    if new_key in no_vowels.keys():
      no_vowels[new_key] = no_vowels[new_key] + my_dict[key]
    else:
      no_vowels[new_key] = my_dict[key]
  no_vowels3 = sort_dict(no_vowels)
  sorted_dict = {}
  for s in no_vowels3:
    sorted_dict[tuple(s)] = no_vowels3.get(s)

  return sorted_dict

'''
Sorts a dictionary and keeps consonants.
'''
def consonants_only(my_dict):
  no_vowels = dict()
  for key in my_dict:
    new_key0 = re.sub("[aeiouyh]", "", key[0])
    new_key1 = re.sub("[aeiouyh]", "", key[1])
    new_key = (new_key0, new_key1)
    new_key = frozenset(new_key)
    if new_key in no_vowels.keys():
      no_vowels[new_key] = no_vowels[new_key] + my_dict[key]
    else:
      no_vowels[new_key] = my_dict[key]
  no_vowels3 = sort_dict(no_vowels)
  sorted_dict = {}
  for s in no_vowels3:
    sorted_dict[tuple(s)] = no_vowels3.get(s)

  return sorted_dict

'''
sorts the dictionary and keeps consonants unless they match each other
'''
def some_consonants_only(my_dict):
  no_vowels = dict()
  for key in my_dict:
    new_key0 = re.sub("[aeiouy]", "", key[0])
    new_key1 = re.sub("[aeiouy]", "", key[1])
    # for loop repeats three times because matching clusters can be up to three units long
    for p in range(3):
      if new_key0 == 'n' and new_key1 == 'ng':
        break
      if new_key0 == 'ng' and new_key1 == 'n':
        break
      if len(new_key0) > 0 and len(new_key1) > 0:
        if new_key0[0] == new_key1[0]:
          l0 = list(new_key0)
          l1 = list(new_key1)
          l0[0] = ''
          l1[0] = ''
          new_key0 = ''.join(l0)
          new_key1 = ''.join(l1)
    new_key = (new_key0, new_key1)
    new_key = frozenset(new_key)
    if new_key in no_vowels.keys():
      no_vowels[new_key] = no_vowels[new_key] + my_dict[key]
    else:
      no_vowels[new_key] = my_dict[key]
  no_vowels3 = sort_dict(no_vowels)
  sorted_dict = {}
  for s in no_vowels3:
    sorted_dict[tuple(s)] = no_vowels3.get(s)

  return sorted_dict


'''
code to remove the vowels of the perfect rhymes to see which consonants are used
most.
'''
def consonants_only_perfect(my_dict):
  no_vowels = dict()
  for key in my_dict:
    new_key0 = re.sub("[aeiouyh]", "", key)
    new_key = new_key0
    if new_key in no_vowels.keys():
      no_vowels[new_key] = no_vowels[new_key] + my_dict[key]
    else:
      no_vowels[new_key] = my_dict[key]
  no_vowels3 = sort_dict(no_vowels)
  sorted_dict = {}
  for s in no_vowels3:
    sorted_dict[s] = no_vowels3.get(s)
  return sorted_dict

# %% [markdown]
# The code below can be used to obtain sorted dictionaries

# %%
sorted_perfect = sort_dict(types_perfect)
sorted_imperfect = sort_dict(types_imperfect)
print(sorted_perfect)
print(sorted_imperfect)
# Out:
# {'uw': 56, 'iy': 52, 'ayt': 30, 'ay': 30, 'ey': 25, 'ow': 24, 'aon': 17, 'ahn': 13, 'ehr': 12, 'aynd': 11, 'own': 10, 'aor': 9, 'iyz': 8, 'eys': 8, 'ayd': 8, 'ahv': 8, 'er': 7, 'ihng': 7, 'ihn': 5, 'ayz': 5, 'iyt': 5, 'aym': 4, 'owld': 4, 'eyz': 4, 'owl': 4, 'uwz': 4, 'aed': 3, 'aend': 3, '': 3, 'aet': 3, 'awnd': 3, 'awn': 3, 'aw': 2, 'oyz': 2, 'ays': 2, 'aart': 2, 'uwm': 2, 'aen': 2, 'ehd': 2, 'aost': 2, 'aong': 2, 'ehnt': 1, 'owz': 1, 'aord': 1, 'aat': 1, 'ihps': 1, 'ayn': 1, 'eyd': 1, 'ert': 1, 'erv': 1, 'iyd': 1, 'eyv': 1, 'ahm': 1, 'ihp': 1, 'uwp': 1, 'awt': 1, 'uhd': 1, 'ehnd': 1, 'ehl': 1, 'aek': 1, 'ihl': 1, 'awd': 1, 'uwk': 1, 'aens': 1, 'ayl': 1}
# {('ahn', 'ahv'): 9, ('ay', 'ayd'): 9, ('awnd', 'awn'): 9, ('iy', 'iyz'): 8, ('ahv', 'ahn'): 8, ('own', 'owm'): 8, ('iyk', 'iy'): 6, ('aym', 'ay'): 5, ('ayts', 'ays'): 4, ('aon', 'aong'): 4, ('iy', 'iyt'): 4, ('iyt', 'iy'): 4, ('aaz', 'aaks'): 4, ('ahn', 'ahz'): 4, ('owm', 'own'): 4, ('ahn', 'ahm'): 4, ('uw', 'uwl'): 4, ('aos', 'aost'): 4, ('awn', 'awnd'): 3, ('aym', 'ayn'): 3, ('ays', 'ay'): 3, ('aym', 'ayd'): 3, ('ihn', 'ihs'): 3, ('ahn', 'ahs'): 3, ('owl', 'ow'): 3, ('ae', 'aen'): 3, ('ihn', 'ihng'): 3, ('ayd', 'ay'): 3, ('aat', 'aan'): 3, ('ayk', 'ayf'): 2, ('aym', 'aynd'): 2, ('aaks', 'aaz'): 2, ('awd', 'awt'): 2, ('ehr', 'ehn'): 2, ('ae', 'aed'): 2, ('ayd', 'aym'): 2, ('iyz', 'iyr'): 2, ('ehdz', 'ehd'): 2, ('ayz', 'ayt'): 2, ('ehls', 'ehlf'): 2, ('uwz', 'uw'): 2, ('ehts', 'ehnts'): 2, ('ehrz', 'ehr'): 2, ('aong', 'aon'): 2, ('ihng', 'ihn'): 2, ('ahp', 'aht'): 2, ('ey', 'eys'): 2, ('aynd', 'ayn'): 2, ('iyz', 'iy'): 2, ('iht', 'ihps'): 2, ('uwz', 'uwsh'): 2, ('ahz', 'ahs'): 2, ('uwsh', 'uwz'): 2, ('ahl', 'ahn'): 2, ('iht', 'ihd'): 2, ('ihp', 'ihps'): 2, ('ihl', 'iht'): 2, ('iyn', 'iy'): 1, ('aan', 'aaz'): 1, ('eyb', 'eyd'): 1, ('aap', 'aart'): 1, ('aar', 'aa'): 1, ('ahn', 'ahnt'): 1, ('ehr', 'ehrz'): 1, ('ahnt', 'ahl'): 1, ('erth', 'ercht'): 1, ('erth', 'erch'): 1, ('ay', 'ays'): 1, ('aed', 'ae'): 1, ('eymz', 'eyn'): 1, ('ays', 'ayts'): 1, ('ayn', 'aym'): 1, ('ayf', 'ayt'): 1, ('aed', 'aes'): 1, ('ow', 'owm'): 1, ('iyk', 'iyt'): 1, ('ahs', 'ah'): 1, ('ahn', 'aht'): 1, ('uwt', 'uw'): 1, ('ihjh', 'ihr'): 1, ('aet', 'aek'): 1, ('aan', 'aat'): 1, ('ey', 'eyks'): 1, ('owld', 'owm'): 1, ('ihl', 'ihm'): 1, ('ahs', 'ahl'): 1, ('uwl', 'uw'): 1, ('ehlf', 'ehls'): 1, ('aarts', 'aart'): 1, ('er', 'erd'): 1, ('aym', 'ayv'): 1, ('aark', 'aard'): 1, ('erld', 'erl'): 1, ('aen', 'aes'): 1, ('awt', 'awn'): 1, ('aen', 'aed'): 1, ('ehn', 'ehr'): 1, ('aend', 'aen'): 1, ('erld', 'erlz'): 1, ('ey', 'eyv'): 1, ('uw', 'uwt'): 1, ('ahm', 'ahs'): 1, ('awt', 'awnd'): 1, ('aw', 'awnd'): 1, ('awnt', 'awn'): 1, ('awnt', 'awnd'): 1, ('awnt', 'awt'): 1, ('aym', 'ayt'): 1, ('ayt', 'aym'): 1, ('eym', 'ey'): 1, ('ey', 'eym'): 1, ('ahs', 'ahm'): 1}
